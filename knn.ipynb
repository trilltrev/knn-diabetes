# %%
import pandas as pd

import seaborn as sns

# %%
data = pd.read_csv("diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# data

# %%
my_data = data.head(20)

# %%
my_data
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
my_data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.181410      -0.058186      -0.806660
# Glucose                      0.181410  1.000000       0.219686       0.016168
# BloodPressure               -0.058186  0.219686       1.000000       0.008259
# SkinThickness               -0.806660  0.016168       0.008259       1.000000
# Insulin                     -0.486759  0.553790       0.036305       0.461601
# BMI                         -0.386041 -0.072565      -0.314031       0.450973
# DiabetesPedigreeFunction    -0.039599  0.209934      -0.041423       0.103832
# Age                          0.182946  0.667874       0.308379       0.043219
# Outcome                     -0.015099  0.452664       0.098262       0.209843
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.486759 -0.386041                 -0.039599
# ...

# %%
sns.heatmap(my_data.corr());

# %%
# glucose or insulin highly affects output or target variable
#choose glucose and insulin for knn

# %%
new_data = my_data.drop('Pregnancies',axis=1)

# %%
new_data1 = new_data.drop('SkinThickness',axis=1)
new_data2 = new_data1.drop('BloodPressure',axis=1)
new_data3 = new_data2.drop('BMI',axis=1)
new_data4 = new_data3.drop('Age',axis=1)
new_data5 = new_data4.drop('DiabetesPedigreeFunction',axis=1)

# %%
new_data5
# Out:
#     Glucose  Insulin  Outcome
# 0       148        0        1
# 1        85        0        0
# 2       183        0        1
# 3        89       94        0
# 4       137      168        1
# 5       116        0        0
# 6        78       88        1
# 7       115        0        0
# 8       197      543        1
# 9       125        0        1
# 10      110        0        0
# 11      168        0        1
# 12      139        0        0
# 13      189      846        1
# 14      166      175        1
# 15      100        0        1
# 16      118      230        1
# 17      107        0        1
# 18      103       83        0
# 19      115       96        1

# %%
my_newdata = new_data5.drop('Outcome',axis=1)

# %%
 my_newdata
# Out:
#     Glucose  Insulin
# 0       148        0
# 1        85        0
# 2       183        0
# 3        89       94
# 4       137      168
# 5       116        0
# 6        78       88
# 7       115        0
# 8       197      543
# 9       125        0
# 10      110        0
# 11      168        0
# 12      139        0
# 13      189      846
# 14      166      175
# 15      100        0
# 16      118      230
# 17      107        0
# 18      103       83
# 19      115       96

# %%
# random value for glucose 160,35
user_data = [160,35]

# %%
colums = list(my_newdata)

# %%
colums
# Out:
# ['Glucose', 'Insulin']

# %%
#lets find distance between users points

# %%
data_arr = []
dist_arr=[]

for i in range(0,20):
    for j in colums:
        print(my_newdata[j][i])
        elem = my_newdata[j][i]
        data_arr.append(elem)
    print(data_arr)
    dist = ((user_data[0]-data_arr[0]) **2 + (user_data[1]-data_arr[1]) **2) **0.5
    dist_arr.append(dist)
    data_arr = []
# Out:
# 148
# 0
# [148, 0]
# 85
# 0
# [85, 0]
# 183
# 0
# [183, 0]
# 89
# 94
# [89, 94]
# 137
# 168
# [137, 168]
# 116
# 0
# [116, 0]
# 78
# 88
# [78, 88]
# 115
# 0
# [115, 0]
# 197
# 543
# [197, 543]
# 125
# 0
# [125, 0]
# 110
# 0
# [110, 0]
# 168
# 0
# [168, 0]
# 139
# 0
# [139, 0]
# 189
# 846
# [189, 846]
# 166
# 175
# [166, 175]
# 100
# 0
# [100, 0]
# 118
# 230
# [118, 230]
# 107
# 0
# [107, 0]
# 103
# 83
# [103, 83]
# 115
# 96
# [115, 96]

# %%
dist_arr
# Out:
# [37.0,
#  82.76472678623425,
#  41.88078318274385,
#  92.31467922275417,
#  134.97407158413796,
#  56.22277118748239,
#  97.63708311906906,
#  57.0087712549569,
#  509.3456586641335,
#  49.49747468305833,
#  61.032778078668514,
#  35.90264614203248,
#  40.8166632639171,
#  811.5183300456004,
#  140.12851244482687,
#  69.46221994724903,
#  199.47180251855147,
#  63.51377803280167,
#  74.51845409024533,
#  75.8023746329889]

# %%
results = pd.DataFrame(dist_arr)

# %%
 results
# Out:
#              0
# 0    37.000000
# 1    82.764727
# 2    41.880783
# 3    92.314679
# 4   134.974072
# 5    56.222771
# 6    97.637083
# 7    57.008771
# 8   509.345659
# 9    49.497475
# 10   61.032778
# 11   35.902646
# 12   40.816663
# 13  811.518330
# 14  140.128512
# 15   69.462220
# 16  199.471803
# 17   63.513778
# 18   74.518454
# 19   75.802375

# %%
results['Glucose'] = my_newdata['Glucose']

# %%
results['Insulin'] = my_newdata['Insulin']
results['Diabetes'] = new_data5['Outcome']

# %%
results
# Out:
#              0  Glucose  Insulin  Diabetes
# 0    37.000000      148        0         1
# 1    82.764727       85        0         0
# 2    41.880783      183        0         1
# 3    92.314679       89       94         0
# 4   134.974072      137      168         1
# 5    56.222771      116        0         0
# 6    97.637083       78       88         1
# 7    57.008771      115        0         0
# 8   509.345659      197      543         1
# 9    49.497475      125        0         1
# 10   61.032778      110        0         0
# 11   35.902646      168        0         1
# 12   40.816663      139        0         0
# 13  811.518330      189      846         1
# 14  140.128512      166      175         1
# 15   69.462220      100        0         1
# 16  199.471803      118      230         1
# 17   63.513778      107        0         1
# 18   74.518454      103       83         0
# 19   75.802375      115       96         1

# %%
# knn need to know k value

k = 20 ** 0.5

# %%
k
# Out:
# 4.47213595499958

# %%
k=5

# %%
results.nsmallest(5,[0])
# Out:
#             0  Glucose  Insulin  Diabetes
# 11  35.902646      168        0         1
# 0   37.000000      148        0         1
# 12  40.816663      139        0         0
# 2   41.880783      183        0         1
# 9   49.497475      125        0         1

# %%
# values of 1 is more than 0, in diabetes column.
# the user has a chance of having diabetes
